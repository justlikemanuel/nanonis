# %%
from nanonisTCP import nanonisTCP
from nanonisTCP.Scan import Scan

# %%
TCP_IP  = '127.0.0.1'               # Local host
TCP_PORT= 6501                      # Check available ports in NANONIS > File > Settings Options > TCP Programming Interface

NTCP = nanonisTCP(TCP_IP, TCP_PORT) # This is how you establish a TCP connection. NTCP is the connection handle.
# Out:
# Heloooo

# %%
# test Scan module
scan_module = Scan(NTCP)
print(scan_module.PropsGet())
scan_module.PropsSet(series_name="%y%m%d_SPM_")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[8], line 3
#       1 # test Scan module
#       2 scan_module = Scan(NTCP)
# ----> 3 print(scan_module.PropsGet())
#       4 scan_module.PropsSet(series_name="%y%m%d_SPM_")
#
# File c:\Users\simon\anaconda3\envs\fmq_test\Lib\site-packages\nanonisTCP\Scan.py:407, in Scan.PropsGet(self)
#     404 self.nanonisTCP.send_command(hex_rep)
#     406 # Receive Response
# --> 407 response = self.nanonisTCP.receive_response()
#     409 continuous_scan = self.nanonisTCP.hex_to_uint32(response[0:4])
#     410 bouncy_scan     = self.nanonisTCP.hex_to_uint32(response[4:8])
#
# File c:\Users\simon\anaconda3\envs\fmq_test\Lib\site-packages\nanonisTCP\nanonisTCP.py:109, in nanonisTCP.receive_response(self, error_index, keep_header)
#      99 def receive_response(self, error_index=-1, keep_header = False):
#     100     """
#     101     Parameters
#     102     error_index : index of 'error status' within the body. -1 skip check
#    (...)    107
#     108     """
# --> 109     response = self.s.recv(self.max_buf_size)                               # Read the response
#     110     body_size = self.hex_to_int32(response[32:36])
#     111     while(True):
#
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen

# %%
bias = Bias(NTCP)                   # Nanonis Bias Module - Pass in the connection handle

#bias.Set(1)                       # Set bias to 1.1 V
v = bias.Get()                      # Get the current bias
print("Bias: " + str(v) + " V")     # Confirm bias has been set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bias = Bias(NTCP)                   # Nanonis Bias Module - Pass in the connection handle
#       3 #bias.Set(1)                       # Set bias to 1.1 V
#       4 v = bias.Get()                      # Get the current bias
#
# NameError: name 'Bias' is not defined

# %%
# NTCP.close_connection()             # Close the connection.
